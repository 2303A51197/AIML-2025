# %% [markdown]
# <a href="https://colab.research.google.com/github/2303A51197/AIML-2025/blob/main/Lab06.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

df=pd.read_table("/content/Classified_Data.txt",sep=',',index_col=0)
df.head()
# Out:
# from matplotlib import pyplot as plt
# _df_24['index'].plot(kind='line', figsize=(8, 4), title='index')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_25['WTT'].plot(kind='line', figsize=(8, 4), title='WTT')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_26['PTI'].plot(kind='line', figsize=(8, 4), title='PTI')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_27['EQW'].plot(kind='line', figsize=(8, 4), title='EQW')
# plt.gca().spines[['top', 'right']].set_visible(False)
#         WTT       PTI       EQW       SBI       LQE       QWG       FDJ  \
# 0  0.913917  1.162073  0.567946  0.755464  0.780862  0.352608  0.759697
# 1  0.635632  1.003722  0.535342  0.825645  0.924109  0.648450  0.675334
# 2  0.721360  1.201493  0.921990  0.855595  1.526629  0.720781  1.626351
# ...

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

# %%
scaler.fit(df.drop('TARGET CLASS',axis=1))
scaled_features = scaler.transform(df.drop('TARGET CLASS',axis=1))

# %%
df_feat=pd.DataFrame(scaled_features,columns=df.columns[:-1])
df_feat.head()
# Out:
#         WTT       PTI       EQW       SBI       LQE       QWG       FDJ  \
# 0 -0.123542  0.185907 -0.913431  0.319629 -1.033637 -2.308375 -0.798951
# 1 -1.084836 -0.430348 -1.025313  0.625388 -0.444847 -1.152706 -1.129797
# 2 -0.788702  0.339318  0.301511  0.755873  2.031693 -0.870156  2.599818
# 3  0.982841  1.060193 -0.621399  0.625299  0.452820 -0.267220  1.750208
# 4  1.139275 -0.640392 -0.709819 -0.057175  0.822886 -0.936773  0.596782
#
#         PJF       HQE       NXJ
# 0 -1.482368 -0.949719 -0.643314
# 1 -0.202240 -1.828051  0.636759
# 2  0.285707 -0.682494 -0.377850
# 3  1.066491  1.241325 -1.026987
# 4 -1.472352  1.040772  0.276510

# %%
from sklearn.model_selection import train_test_split
X=df_feat
Y=df['TARGET CLASS']
X_train, X_test, Y_train, Y_test=train_test_split(scaled_features,df['TARGET CLASS'],test_size=0.20, random_state=10)

# %%
from sklearn.neighbors import KNeighborsClassifier
knn=KNeighborsClassifier(n_neighbors=1)
knn.fit(X_train,Y_train)
# Out:
# KNeighborsClassifier(n_neighbors=1)

# %%
pred=knn.predict(X_test)

# %%
from sklearn.metrics import classification_report, confusion_matrix
conf_mat=confusion_matrix(Y_test,pred)
print(conf_mat)
# Out:
# [[102  10]
#  [  6  82]]

# %%
print(classification_report(Y_test,pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.94      0.91      0.93       112
#            1       0.89      0.93      0.91        88
#
#     accuracy                           0.92       200
#    macro avg       0.92      0.92      0.92       200
# weighted avg       0.92      0.92      0.92       200

# %%
print("Misclassification error rate: ",round(np.mean(pred!=Y_test),3))
# Out:
# Misclassification error rate:  0.08
